# %% [markdown]
# # 0.0 Imports

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import sklearn.metrics as mt
from lightgbm import LGBMRegressor

# %% [markdown]
# # 0.1 - Load Datasets

# %%
actual_folder = Path.cwd()
print(actual_folder)

main_folder = actual_folder.parent
print(main_folder)

path_folder_dataset = main_folder / 'dataset' / 'regression_datasets'

if path_folder_dataset.exists():
    print(f'Caminho existente: {path_folder_dataset}')
else:
    print(f'Erro: O arquivo não foi encontrado {path_folder_dataset}')
# Out:
# d:\repos\projetos\ml_trials_algorithm\notebooks
# d:\repos\projetos\ml_trials_algorithm
# Caminho existente: d:\repos\projetos\ml_trials_algorithm\dataset\regression_datasets

# %%
#Carrega os datasets da pasta - Treinamento / Validação e Teste

dataset_traning_X = path_folder_dataset / 'a_traninig' / 'X_training.csv'
dataset_traning_y = path_folder_dataset / 'a_traninig' / 'y_training.csv'

dataset_validation_X = path_folder_dataset / 'b_validation' / 'X_validation.csv'
dataset_validation_y = path_folder_dataset / 'b_validation' / 'y_validation.csv'

dataset_test_X = path_folder_dataset / 'c_test' / 'X_test.csv'
dataset_test_y = path_folder_dataset / 'c_test' / 'y_test.csv'

X_train = pd.read_csv(dataset_traning_X)
y_train = pd.read_csv(dataset_traning_y)

X_val = pd.read_csv(dataset_validation_X)
y_val = pd.read_csv(dataset_validation_y)

X_test = pd.read_csv(dataset_test_X)
y_test = pd.read_csv(dataset_test_y)

# %% [markdown]
# # 1.0 - Training Algorithm

# %% [markdown]
# ## Passo 2 — Treino com parâmetros default

# %%
# Instanciar o modelo com parâmetros default
model_def = LGBMRegressor(verbosity=-1, random_state=42)

# Treinar com dados de treino
model_def.fit(X_train, y_train.values.ravel())

# Predições no treino e na validação
yhat_train_def = model_def.predict(X_train)
yhat_val_def   = model_def.predict(X_val)

# %% [markdown]
# ## Passo 3 — Performance no treino (default)

# %%
# Métricas no conjunto de TREINO com parâmetros default
r2_train_def   = mt.r2_score(y_train, yhat_train_def)
mse_train_def  = mt.mean_squared_error(y_train, yhat_train_def)
rmse_train_def = np.sqrt(mse_train_def)
mae_train_def  = mt.mean_absolute_error(y_train, yhat_train_def)
mape_train_def = mt.mean_absolute_percentage_error(y_train, yhat_train_def)

print("--- Performance no Treino (Default) ---")
print(f"R²:   {r2_train_def:.4f}")
print(f"MSE:  {mse_train_def:.2f}")
print(f"RMSE: {rmse_train_def:.2f}")
print(f"MAE:  {mae_train_def:.2f}")
print(f"MAPE: {mape_train_def * 100:.2f}%")

# %% [markdown]
# ## Passo 4 — Performance na validação (default)

# %%
# Métricas no conjunto de VALIDAÇÃO com parâmetros default
r2_val_def   = mt.r2_score(y_val, yhat_val_def)
mse_val_def  = mt.mean_squared_error(y_val, yhat_val_def)
rmse_val_def = np.sqrt(mse_val_def)
mae_val_def  = mt.mean_absolute_error(y_val, yhat_val_def)
mape_val_def = mt.mean_absolute_percentage_error(y_val, yhat_val_def)

print("--- Performance na Validação (Default) ---")
print(f"R²:   {r2_val_def:.4f}")
print(f"MSE:  {mse_val_def:.2f}")
print(f"RMSE: {rmse_val_def:.2f}")
print(f"MAE:  {mae_val_def:.2f}")
print(f"MAPE: {mape_val_def * 100:.2f}%")

# %% [markdown]
# ## Passo 5 — Ajuste de hiperparâmetros

# %%
print("--- Testando Múltiplos Hiperparâmetros no LightGBM (Regressão) ---")
melhor_n_estimators = 100
melhor_num_leaves = 31
melhor_learning_rate = 0.1
melhor_min_child_samples = 20
melhor_r2_val = -999

# Grades de hiperparâmetros para o novo ecossistema de Boosting
list_n_estimators = [100, 300, 500]
list_num_leaves = [15, 31, 63]  # Equivale a max_depths aproximados de 4, 5 e 6
list_learning_rate = [0.01, 0.05, 0.1]
list_min_child_samples = [10, 20, 50]

# LOOP QUADRUPLO: Varre o espaço de busca do LightGBM
for n_est in list_n_estimators:
    for nl in list_num_leaves:
        for lr in list_learning_rate:
            for mcs in list_min_child_samples:
                
                # Instancia o regressor da Microsoft
                # verbosity=-1 desativa os logs internos repetitivos do LightGBM
                model = LGBMRegressor(
                    n_estimators=n_est,
                    num_leaves=nl,
                    learning_rate=lr,
                    min_child_samples=mcs,
                    n_jobs=-1,
                    verbosity=-1,
                    random_state=42
                )
                
                try:
                    model.fit(X_train, y_train.values.ravel())
                    
                    yhat_train = model.predict(X_train)
                    yhat_val = model.predict(X_val)
                    
                    r2_train = mt.r2_score(y_train, yhat_train)
                    r2_val = mt.r2_score(y_val, yhat_val)
                    rmse_val = np.sqrt(mt.mean_squared_error(y_val, yhat_val))
                    
                    print(f"N_Est: {n_est} | Leaves: {nl} | LR: {lr:<4} | Min_Child: {mcs} | R² Treino: {r2_train:.4f} | R² Val: {r2_val:.4f}")
                    
                    if r2_val > melhor_r2_val:
                        melhor_r2_val = r2_val
                        melhor_n_estimators = n_est
                        melhor_num_leaves = nl
                        melhor_learning_rate = lr
                        melhor_min_child_samples = mcs
                        
                except Exception as e:
                    print(f"Erro na combinação N_Est {n_est} | Leaves {nl} | LR {lr} | Min_Child {mcs}: {e}")

print("=" * 90)
print(f"-> VENCEDOR DO ENSAIO LIGHTGBM:")
print(f"Melhor N_Estimators: {melhor_n_estimators}")
print(f"Melhor Num_Leaves: {melhor_num_leaves}")
print(f"Melhor Learning_Rate: {melhor_learning_rate}")
print(f"Melhor Min_Child_Samples: {melhor_min_samples_split if 'melhor_min_samples_split' in locals() else melhor_min_child_samples}")
print(f"Maior R² obtido na Validação: {melhor_r2_val:.4f}\n")
# Out:
# --- Testando Múltiplos Hiperparâmetros no LightGBM (Regressão) ---
# N_Est: 100 | Leaves: 15 | LR: 0.01 | Min_Child: 10 | R² Treino: 0.0984 | R² Val: 0.0800
# N_Est: 100 | Leaves: 15 | LR: 0.01 | Min_Child: 20 | R² Treino: 0.0984 | R² Val: 0.0807
# N_Est: 100 | Leaves: 15 | LR: 0.01 | Min_Child: 50 | R² Treino: 0.0973 | R² Val: 0.0795
# N_Est: 100 | Leaves: 15 | LR: 0.05 | Min_Child: 10 | R² Treino: 0.2148 | R² Val: 0.1392
# N_Est: 100 | Leaves: 15 | LR: 0.05 | Min_Child: 20 | R² Treino: 0.2160 | R² Val: 0.1401
# N_Est: 100 | Leaves: 15 | LR: 0.05 | Min_Child: 50 | R² Treino: 0.2122 | R² Val: 0.1391
# N_Est: 100 | Leaves: 15 | LR: 0.1  | Min_Child: 10 | R² Treino: 0.2983 | R² Val: 0.1632
# N_Est: 100 | Leaves: 15 | LR: 0.1  | Min_Child: 20 | R² Treino: 0.2887 | R² Val: 0.1586
# N_Est: 100 | Leaves: 15 | LR: 0.1  | Min_Child: 50 | R² Treino: 0.2863 | R² Val: 0.1615
# N_Est: 100 | Leaves: 31 | LR: 0.01 | Min_Child: 10 | R² Treino: 0.1403 | R² Val: 0.1032
# N_Est: 100 | Leaves: 31 | LR: 0.01 | Min_Child: 20 | R² Treino: 0.1387 | R² Val: 0.1030
# N_Est: 100 | Leaves: 31 | LR: 0.01 | Min_Child: 50 | R² Treino: 0.1361 | R² Val: 0.1012
# N_Est: 100 | Leaves: 31 | LR: 0.05 | Min_Child: 10 | R² Treino: 0.3232 | R² Val: 0.1769
# N_Est: 100 | Leaves: 31 | LR: 0.05 | Min_Child: 20 | R² Treino: 0.3191 | R² Val: 0.1758
# N_Est: 100 | Leaves: 31 | LR: 0.05 | Min_Child: 50 | R² Treino: 0.3110 | R² Val: 0.1736
# N_Est: 100 | Leaves: 31 | LR: 0.1  | Min_Child: 10 | R² Treino: 0.4467 | R² Val: 0.2022
# N_Est: 100 | Leaves: 31 | LR: 0.1  | Min_Child: 20 | R² Treino: 0.4374 | R² Val: 0.2029
# N_Est: 100 | Leaves: 31 | LR: 0.1  | Min_Child: 50 | R² Treino: 0.4244 | R² Val: 0.2083
# N_Est: 100 | Leaves: 63 | LR: 0.01 | Min_Child: 10 | R² Treino: 0.1996 | R² Val: 0.1295
# N_Est: 100 | Leaves: 63 | LR: 0.01 | Min_Child: 20 | R² Treino: 0.1963 | R² Val: 0.1274
# N_Est: 100 | Leaves: 63 | LR: 0.01 | Min_Child: 50 | R² Treino: 0.1891 | R² Val: 0.1247
# N_Est: 100 | Leaves: 63 | LR: 0.05 | Min_Child: 10 | R² Treino: 0.4731 | R² Val: 0.2160
# N_Est: 100 | Leaves: 63 | LR: 0.05 | Min_Child: 20 | R² Treino: 0.4643 | R² Val: 0.2177
# N_Est: 100 | Leaves: 63 | LR: 0.05 | Min_Child: 50 | R² Treino: 0.4434 | R² Val: 0.2155
# N_Est: 100 | Leaves: 63 | LR: 0.1  | Min_Child: 10 | R² Treino: 0.6327 | R² Val: 0.2552
# N_Est: 100 | Leaves: 63 | LR: 0.1  | Min_Child: 20 | R² Treino: 0.6169 | R² Val: 0.2422
# N_Est: 100 | Leaves: 63 | LR: 0.1  | Min_Child: 50 | R² Treino: 0.6006 | R² Val: 0.2347
# N_Est: 300 | Leaves: 15 | LR: 0.01 | Min_Child: 10 | R² Treino: 0.1738 | R² Val: 0.1220
# N_Est: 300 | Leaves: 15 | LR: 0.01 | Min_Child: 20 | R² Treino: 0.1734 | R² Val: 0.1228
# N_Est: 300 | Leaves: 15 | LR: 0.01 | Min_Child: 50 | R² Treino: 0.1703 | R² Val: 0.1199
# N_Est: 300 | Leaves: 15 | LR: 0.05 | Min_Child: 10 | R² Treino: 0.3583 | R² Val: 0.1779
# N_Est: 300 | Leaves: 15 | LR: 0.05 | Min_Child: 20 | R² Treino: 0.3537 | R² Val: 0.1793
# N_Est: 300 | Leaves: 15 | LR: 0.05 | Min_Child: 50 | R² Treino: 0.3457 | R² Val: 0.1799
# N_Est: 300 | Leaves: 15 | LR: 0.1  | Min_Child: 10 | R² Treino: 0.5021 | R² Val: 0.2118
# N_Est: 300 | Leaves: 15 | LR: 0.1  | Min_Child: 20 | R² Treino: 0.4907 | R² Val: 0.2043
# N_Est: 300 | Leaves: 15 | LR: 0.1  | Min_Child: 50 | R² Treino: 0.4748 | R² Val: 0.2050
# N_Est: 300 | Leaves: 31 | LR: 0.01 | Min_Child: 10 | R² Treino: 0.2561 | R² Val: 0.1557
# N_Est: 300 | Leaves: 31 | LR: 0.01 | Min_Child: 20 | R² Treino: 0.2522 | R² Val: 0.1546
# N_Est: 300 | Leaves: 31 | LR: 0.01 | Min_Child: 50 | R² Treino: 0.2459 | R² Val: 0.1538
# N_Est: 300 | Leaves: 31 | LR: 0.05 | Min_Child: 10 | R² Treino: 0.5376 | R² Val: 0.2265
# N_Est: 300 | Leaves: 31 | LR: 0.05 | Min_Child: 20 | R² Treino: 0.5282 | R² Val: 0.2328
# N_Est: 300 | Leaves: 31 | LR: 0.05 | Min_Child: 50 | R² Treino: 0.5087 | R² Val: 0.2239
# N_Est: 300 | Leaves: 31 | LR: 0.1  | Min_Child: 10 | R² Treino: 0.7027 | R² Val: 0.2585
# N_Est: 300 | Leaves: 31 | LR: 0.1  | Min_Child: 20 | R² Treino: 0.6930 | R² Val: 0.2532
# N_Est: 300 | Leaves: 31 | LR: 0.1  | Min_Child: 50 | R² Treino: 0.6671 | R² Val: 0.2488
# N_Est: 300 | Leaves: 63 | LR: 0.01 | Min_Child: 10 | R² Treino: 0.3737 | R² Val: 0.1941
# N_Est: 300 | Leaves: 63 | LR: 0.01 | Min_Child: 20 | R² Treino: 0.3649 | R² Val: 0.1924
# N_Est: 300 | Leaves: 63 | LR: 0.01 | Min_Child: 50 | R² Treino: 0.3495 | R² Val: 0.1867
# N_Est: 300 | Leaves: 63 | LR: 0.05 | Min_Child: 10 | R² Treino: 0.7325 | R² Val: 0.2719
# N_Est: 300 | Leaves: 63 | LR: 0.05 | Min_Child: 20 | R² Treino: 0.7245 | R² Val: 0.2680
# N_Est: 300 | Leaves: 63 | LR: 0.05 | Min_Child: 50 | R² Treino: 0.6949 | R² Val: 0.2608
# N_Est: 300 | Leaves: 63 | LR: 0.1  | Min_Child: 10 | R² Treino: 0.8850 | R² Val: 0.2910
# N_Est: 300 | Leaves: 63 | LR: 0.1  | Min_Child: 20 | R² Treino: 0.8688 | R² Val: 0.2679
# N_Est: 300 | Leaves: 63 | LR: 0.1  | Min_Child: 50 | R² Treino: 0.8468 | R² Val: 0.2559
# N_Est: 500 | Leaves: 15 | LR: 0.01 | Min_Child: 10 | R² Treino: 0.2157 | R² Val: 0.1390
# N_Est: 500 | Leaves: 15 | LR: 0.01 | Min_Child: 20 | R² Treino: 0.2155 | R² Val: 0.1399
# N_Est: 500 | Leaves: 15 | LR: 0.01 | Min_Child: 50 | R² Treino: 0.2113 | R² Val: 0.1383
# N_Est: 500 | Leaves: 15 | LR: 0.05 | Min_Child: 10 | R² Treino: 0.4560 | R² Val: 0.2043
# N_Est: 500 | Leaves: 15 | LR: 0.05 | Min_Child: 20 | R² Treino: 0.4515 | R² Val: 0.2040
# N_Est: 500 | Leaves: 15 | LR: 0.05 | Min_Child: 50 | R² Treino: 0.4364 | R² Val: 0.2016
# N_Est: 500 | Leaves: 15 | LR: 0.1  | Min_Child: 10 | R² Treino: 0.6267 | R² Val: 0.2353
# N_Est: 500 | Leaves: 15 | LR: 0.1  | Min_Child: 20 | R² Treino: 0.6101 | R² Val: 0.2315
# N_Est: 500 | Leaves: 15 | LR: 0.1  | Min_Child: 50 | R² Treino: 0.5840 | R² Val: 0.2211
# N_Est: 500 | Leaves: 31 | LR: 0.01 | Min_Child: 10 | R² Treino: 0.3227 | R² Val: 0.1761
# N_Est: 500 | Leaves: 31 | LR: 0.01 | Min_Child: 20 | R² Treino: 0.3191 | R² Val: 0.1762
# N_Est: 500 | Leaves: 31 | LR: 0.01 | Min_Child: 50 | R² Treino: 0.3110 | R² Val: 0.1770
# N_Est: 500 | Leaves: 31 | LR: 0.05 | Min_Child: 10 | R² Treino: 0.6609 | R² Val: 0.2559
# N_Est: 500 | Leaves: 31 | LR: 0.05 | Min_Child: 20 | R² Treino: 0.6511 | R² Val: 0.2568
# N_Est: 500 | Leaves: 31 | LR: 0.05 | Min_Child: 50 | R² Treino: 0.6251 | R² Val: 0.2408
# N_Est: 500 | Leaves: 31 | LR: 0.1  | Min_Child: 10 | R² Treino: 0.8257 | R² Val: 0.2752
# N_Est: 500 | Leaves: 31 | LR: 0.1  | Min_Child: 20 | R² Treino: 0.8161 | R² Val: 0.2679
# N_Est: 500 | Leaves: 31 | LR: 0.1  | Min_Child: 50 | R² Treino: 0.7829 | R² Val: 0.2606
# N_Est: 500 | Leaves: 63 | LR: 0.01 | Min_Child: 10 | R² Treino: 0.4710 | R² Val: 0.2172
# N_Est: 500 | Leaves: 63 | LR: 0.01 | Min_Child: 20 | R² Treino: 0.4613 | R² Val: 0.2183
# N_Est: 500 | Leaves: 63 | LR: 0.01 | Min_Child: 50 | R² Treino: 0.4452 | R² Val: 0.2145
# N_Est: 500 | Leaves: 63 | LR: 0.05 | Min_Child: 10 | R² Treino: 0.8450 | R² Val: 0.2856
# N_Est: 500 | Leaves: 63 | LR: 0.05 | Min_Child: 20 | R² Treino: 0.8371 | R² Val: 0.2815
# N_Est: 500 | Leaves: 63 | LR: 0.05 | Min_Child: 50 | R² Treino: 0.8057 | R² Val: 0.2667
# N_Est: 500 | Leaves: 63 | LR: 0.1  | Min_Child: 10 | R² Treino: 0.9527 | R² Val: 0.2940
# N_Est: 500 | Leaves: 63 | LR: 0.1  | Min_Child: 20 | R² Treino: 0.9445 | R² Val: 0.2699
# N_Est: 500 | Leaves: 63 | LR: 0.1  | Min_Child: 50 | R² Treino: 0.9263 | R² Val: 0.2511
# ==========================================================================================
# -> VENCEDOR DO ENSAIO LIGHTGBM:
# Melhor N_Estimators: 500
# Melhor Num_Leaves: 63
# Melhor Learning_Rate: 0.1
# Melhor Min_Child_Samples: 10
# Maior R² obtido na Validação: 0.2940

# %% [markdown]
# ## Passo 6 — União treino + validação

# %%
# Unir treino + validação para formar o conjunto final de treinamento
X_train_final = pd.concat([X_train, X_val])
y_train_final = pd.concat([y_train, y_val])

print(f"X_train_final shape: {X_train_final.shape}")
print(f"y_train_final shape: {y_train_final.shape}")

# %% [markdown]
# ## Passo 7 — Retreino com melhores parâmetros

# %%
n_est = 500
nl = 63
lr = 0.1
mcs = 10

# Treinando o modelo para ver as outras métricas de avaliação
model = LGBMRegressor(
                    n_estimators=n_est,
                    num_leaves=nl,
                    learning_rate=lr,
                    min_child_samples=mcs,
                    n_jobs=-1,
                    verbosity=-1,
                    random_state=42
                )


model.fit(X_train, y_train.values.ravel())

# Previsão de treino e validação
yhat_train = model.predict(X_train)
yhat_val = model.predict(X_val)

#Performance Train
r2_train = mt.r2_score(y_train, yhat_train)
mse_train = mt.mean_squared_error(y_train, yhat_train)
rmse_train = np.sqrt(mse_train)
mae_train = mt.mean_absolute_error(y_train, yhat_train)
mape_train = mt.mean_absolute_percentage_error(y_train, yhat_train)

#Performance Validation
r2_val = mt.r2_score(y_val, yhat_val)
mse_val = mt.mean_squared_error(y_val, yhat_val)
rmse_val = np.sqrt(mse_val)
mae_val = mt.mean_absolute_error(y_val, yhat_val)
mape_val = mt.mean_absolute_percentage_error(y_val, yhat_val)

# Métrica de Treinamento e Teste
print(f"MÉTRICAS TREINAMENTO:")
print(f"R² (Coef. Determinação): {r2_train:.4f}")
print(f"MSE (Erro Quadrático Médio): {mse_train:.2f}")
print(f"RMSE (Raiz do Erro Quadrático): {rmse_train:.2f}")
print(f"MAE (Erro Absoluto Médio): {mae_train:.2f}")
print(f"MAPE (Erro Percentual Médio): {mape_train * 100:.2f}%")
print("=" * 65)
print(f"MÉTRICAS VALDAÇÃO:")
print(f"R² (Coef. Determinação): {r2_val:.4f}")
print(f"MSE (Erro Quadrático Médio): {mse_val:.2f}")
print(f"RMSE (Raiz do Erro Quadrático): {rmse_val:.2f}")
print(f"MAE (Erro Absoluto Médio): {mae_val:.2f}")
print(f"MAPE (Erro Percentual Médio): {mape_val * 100:.2f}%")
# Out:
# MÉTRICAS TREINAMENTO:
# R² (Coef. Determinação): 0.9527
# MSE (Erro Quadrático Médio): 22.59
# RMSE (Raiz do Erro Quadrático): 4.75
# MAE (Erro Absoluto Médio): 3.11
# MAPE (Erro Percentual Médio): 135.00%
# =================================================================
# MÉTRICAS VALDAÇÃO:
# R² (Coef. Determinação): 0.2940
# MSE (Erro Quadrático Médio): 337.12
# RMSE (Raiz do Erro Quadrático): 18.36
# MAE (Erro Absoluto Médio): 13.12
# MAPE (Erro Percentual Médio): 685.47%

# %% [markdown]
# ## Passo 8 — Performance no teste

# %%
# ==============================================================================
# JUNTAR AS BASES E EXECUTAR O TESTE FINAL
# ==============================================================================
print("--- Executando o Teste Final ---")

# Juntando treino e validação para dar mais volume de dados ao KNN
X_train_final = pd.concat([X_train, X_val])
y_train_final = pd.concat([y_train, y_val])

# Treinando o modelo definitivo com o melhor K encontrado
model = LGBMRegressor(
                    n_estimators=n_est,
                    num_leaves=nl,
                    learning_rate=lr,
                    min_child_samples=mcs,
                    n_jobs=-1,
                    verbosity=-1,
                    random_state=42
                )


model.fit(X_train_final, y_train_final.values.ravel())

# Previsão final usando o dataset de teste (que ficou isolado o tempo todo)
yhat_test = model.predict(X_test)

#Performance Test
r2_test = mt.r2_score(y_test, yhat_test)
mse_test = mt.mean_squared_error(y_test, yhat_test)
rmse_test = np.sqrt(mse_test)
mae_test = mt.mean_absolute_error(y_test, yhat_test)
mape_test = mt.mean_absolute_percentage_error(y_test, yhat_test)

# Métrica final de produção
print(f"MÉTRICAS NO DATASET DE TESTE:")
print(f"R² (Coef. Determinação): {r2_test:.4f}")
print(f"MSE (Erro Quadrático Médio): {mse_test:.2f}")
print(f"RMSE (Raiz do Erro Quadrático): {rmse_test:.2f}")
print(f"MAE (Erro Absoluto Médio): {mae_test:.2f}")
print(f"MAPE (Erro Percentual Médio): {mape_test * 100:.2f}%")
print("=" * 65)
# Out:
# --- Executando o Teste Final ---
# MÉTRICAS NO DATASET DE TESTE:
# R² (Coef. Determinação): 0.3579
# MSE (Erro Quadrático Médio): 312.63
# RMSE (Raiz do Erro Quadrático): 17.68
# MAE (Erro Absoluto Médio): 12.75
# MAPE (Erro Percentual Médio): 632.43%
# =================================================================

# %% [markdown]
# ## Passo 9 — Avaliar e registrar 3 insights
#
# **Insight 1 — [Título do Insight]**
# > [Descreva aqui o insight mais relevante observado no comportamento deste algoritmo com estes dados.]
#
# **Insight 2 — [Título do Insight]**
# > [Descreva aqui o segundo insight: diferença treino vs validação, comportamento dos hiperparâmetros, etc.]
#
# **Insight 3 — [Título do Insight]**
# > [Descreva aqui o terceiro insight: comparação com outras abordagens, limitações, ou pontos de atenção.]

# %% [markdown]
# ## Passo 10 — Quadro Comparativo — Diagnóstico Completo

# %%
data_comparativo = {
    'Conjunto': ['Treino (Default)', 'Validação (Default)', 'Treino (Tunado)', 'Validação (Tunado)', 'Teste (Final)'],
    'R²':    [r2_train_def,   r2_val_def,   '-', '-', r2_test],
    'RMSE':  [rmse_train_def, rmse_val_def, '-', '-', rmse_test],
    'MAE':   [mae_train_def,  mae_val_def,  '-', '-', mae_test],
    'MAPE':  [f'{mape_train_def*100:.2f}%', f'{mape_val_def*100:.2f}%', '-', '-', f'{mape_test*100:.2f}%'],
}
df_comparativo = pd.DataFrame(data_comparativo)
print("\n--- Quadro Comparativo — Diagnóstico Completo ---")
print(df_comparativo.to_string(index=False))
