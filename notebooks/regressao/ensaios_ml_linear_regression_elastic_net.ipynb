# %% [markdown]
# # 0.0 Imports

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.linear_model import ElasticNet
from sklearn import metrics as mt

# %% [markdown]
# # 0.1 - Load Datasets

# %%
actual_folder = Path.cwd()
print(actual_folder)

main_folder = actual_folder.parent
print(main_folder)

path_folder_dataset = main_folder / 'dataset' / 'regression_datasets'

if path_folder_dataset.exists():
    print(f'Caminho existente: {path_folder_dataset}')
else:
    print(f'Erro: O arquivo não foi encontrado {path_folder_dataset}')
# Out:
# d:\repos\projetos\ml_trials_algorithm\notebooks
# d:\repos\projetos\ml_trials_algorithm
# Caminho existente: d:\repos\projetos\ml_trials_algorithm\dataset\regression_datasets

# %%
#Carrega os datasets da pasta - Treinamento / Validação e Teste

dataset_traning_X = path_folder_dataset / 'a_traninig' / 'X_training.csv'
dataset_traning_y = path_folder_dataset / 'a_traninig' / 'y_training.csv'

dataset_validation_X = path_folder_dataset / 'b_validation' / 'X_validation.csv'
dataset_validation_y = path_folder_dataset / 'b_validation' / 'y_validation.csv'

dataset_test_X = path_folder_dataset / 'c_test' / 'X_test.csv'
dataset_test_y = path_folder_dataset / 'c_test' / 'y_test.csv'

X_train = pd.read_csv(dataset_traning_X)
y_train = pd.read_csv(dataset_traning_y)

X_val = pd.read_csv(dataset_validation_X)
y_val = pd.read_csv(dataset_validation_y)

X_test = pd.read_csv(dataset_test_X)
y_test = pd.read_csv(dataset_test_y)

# %% [markdown]
# # 1.0 - Training Algorithm

# %% [markdown]
# ## Passo 2 — Treino com parâmetros default

# %%
# Instanciar o modelo com parâmetros default
model_def = ElasticNet()

# Treinar com dados de treino
model_def.fit(X_train, y_train.values.ravel())

# Predições no treino e na validação
yhat_train_def = model_def.predict(X_train)
yhat_val_def   = model_def.predict(X_val)

# %% [markdown]
# ## Passo 3 — Performance no treino (default)

# %%
# Métricas no conjunto de TREINO com parâmetros default
r2_train_def   = mt.r2_score(y_train, yhat_train_def)
mse_train_def  = mt.mean_squared_error(y_train, yhat_train_def)
rmse_train_def = np.sqrt(mse_train_def)
mae_train_def  = mt.mean_absolute_error(y_train, yhat_train_def)
mape_train_def = mt.mean_absolute_percentage_error(y_train, yhat_train_def)

print("--- Performance no Treino (Default) ---")
print(f"R²:   {r2_train_def:.4f}")
print(f"MSE:  {mse_train_def:.2f}")
print(f"RMSE: {rmse_train_def:.2f}")
print(f"MAE:  {mae_train_def:.2f}")
print(f"MAPE: {mape_train_def * 100:.2f}%")

# %% [markdown]
# ## Passo 4 — Performance na validação (default)

# %%
# Métricas no conjunto de VALIDAÇÃO com parâmetros default
r2_val_def   = mt.r2_score(y_val, yhat_val_def)
mse_val_def  = mt.mean_squared_error(y_val, yhat_val_def)
rmse_val_def = np.sqrt(mse_val_def)
mae_val_def  = mt.mean_absolute_error(y_val, yhat_val_def)
mape_val_def = mt.mean_absolute_percentage_error(y_val, yhat_val_def)

print("--- Performance na Validação (Default) ---")
print(f"R²:   {r2_val_def:.4f}")
print(f"MSE:  {mse_val_def:.2f}")
print(f"RMSE: {rmse_val_def:.2f}")
print(f"MAE:  {mae_val_def:.2f}")
print(f"MAPE: {mape_val_def * 100:.2f}%")

# %% [markdown]
# ## Passo 5 — Ajuste de hiperparâmetros

# %%
print("--- Testando Múltiplos Hiperparâmetros na Elastic Net ---")
melhor_alpha = 1.0
melhor_l1_ratio = 0.5
melhor_max_iter = 1000
melhor_r2_val = -999

list_alpha = [0.0001, 0.001, 0.01, 0.1, 1.0]
list_l1_ratio = [0.1, 0.3, 0.5, 0.7, 0.9]
list_max_iter = [1000, 2000, 3000]

for alpha in list_alpha:
    for l1_rat in list_l1_ratio:
        for mi in list_max_iter:
        
            # Instancia o Lasso com os parâmetros do loop
            model = ElasticNet(alpha=alpha, l1_ratio=l1_rat, max_iter=mi, random_state=42)
        
            # O try/except agora serve para pular APENAS problemas matemáticos reais de convergência brutos,
            # mas as variáveis e métricas foram limpas.
            try:
                model.fit(X_train, y_train.values.ravel())
            
                yhat_train = model.predict(X_train)
                yhat_val = model.predict(X_val)
            
                r2_train = mt.r2_score(y_train, yhat_train)
                r2_val = mt.r2_score(y_val, yhat_val)
                rmse_val = np.sqrt(mt.mean_squared_error(y_val, yhat_val))
                mae_val = mt.mean_absolute_error(y_val, yhat_val)
            
                # Blindagem do MAPE: calcula em formato bruto primeiro
                mape_raw = mt.mean_absolute_percentage_error(y_val, yhat_val)
                # Se o MAPE for infinito ou absurdamente grande devido aos zeros, tratamos como string
                mape_print = f"{mape_raw * 100:.2f}%" if np.isfinite(mape_raw) and mape_raw < 1000 else "Distort (High)"
            
                print(f"Alpha: {alpha:<6} | Max_Iter: {mi:4d} | R² Treino: {r2_train:.4f} | R² Val: {r2_val:.4f} | RMSE Val: {rmse_val:.2f} | MAPE Val: {mape_print}")
            
                if r2_val > melhor_r2_val:
                    melhor_r2_val = r2_val
                    melhor_alpha = alpha
                    melhor_max_iter = mi
                
            except Exception as e:
                # Se falhar, agora ele te avisa o MOTIVO real do erro no print
                print(f"Erro real na combinação Alpha {alpha} | Max_Iter {mi}: {e}")

print("=" * 80)
print(f"-> VENCEDOR DO ENSAIO ELASTIC NET:")
print(f"Melhor Alpha: {melhor_alpha}")
print(f"Melhor L1_Ratio: {melhor_l1_ratio}")
print(f"Melhor Max_Iter: {melhor_max_iter}")
print(f"Maior R² obtido na Validação: {melhor_r2_val:.4f}\n")
# Out:
# --- Testando Múltiplos Hiperparâmetros na Regressão Ridge (L2) ---
# Alpha: 0.0001 | Max_Iter: 1000 | R² Treino: 0.0461 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.24%
# Alpha: 0.0001 | Max_Iter: 2000 | R² Treino: 0.0461 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.24%
# Alpha: 0.0001 | Max_Iter: 3000 | R² Treino: 0.0461 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.24%
# Alpha: 0.0001 | Max_Iter: 1000 | R² Treino: 0.0461 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.25%
# Alpha: 0.0001 | Max_Iter: 2000 | R² Treino: 0.0461 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.25%
# Alpha: 0.0001 | Max_Iter: 3000 | R² Treino: 0.0461 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.25%
# Alpha: 0.0001 | Max_Iter: 1000 | R² Treino: 0.0461 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.25%
# Alpha: 0.0001 | Max_Iter: 2000 | R² Treino: 0.0461 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.25%
# Alpha: 0.0001 | Max_Iter: 3000 | R² Treino: 0.0461 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.25%
# Alpha: 0.0001 | Max_Iter: 1000 | R² Treino: 0.0461 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.25%
# Alpha: 0.0001 | Max_Iter: 2000 | R² Treino: 0.0461 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.25%
# Alpha: 0.0001 | Max_Iter: 3000 | R² Treino: 0.0461 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.25%
# Alpha: 0.0001 | Max_Iter: 1000 | R² Treino: 0.0461 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.26%
# Alpha: 0.0001 | Max_Iter: 2000 | R² Treino: 0.0461 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.26%
# Alpha: 0.0001 | Max_Iter: 3000 | R² Treino: 0.0461 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.26%
# Alpha: 0.001  | Max_Iter: 1000 | R² Treino: 0.0460 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.14%
# Alpha: 0.001  | Max_Iter: 2000 | R² Treino: 0.0460 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.14%
# Alpha: 0.001  | Max_Iter: 3000 | R² Treino: 0.0460 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.14%
# Alpha: 0.001  | Max_Iter: 1000 | R² Treino: 0.0460 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.17%
# Alpha: 0.001  | Max_Iter: 2000 | R² Treino: 0.0460 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.17%
# Alpha: 0.001  | Max_Iter: 3000 | R² Treino: 0.0460 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.17%
# Alpha: 0.001  | Max_Iter: 1000 | R² Treino: 0.0460 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.21%
# Alpha: 0.001  | Max_Iter: 2000 | R² Treino: 0.0460 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.21%
# Alpha: 0.001  | Max_Iter: 3000 | R² Treino: 0.0460 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.21%
# Alpha: 0.001  | Max_Iter: 1000 | R² Treino: 0.0460 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.24%
# Alpha: 0.001  | Max_Iter: 2000 | R² Treino: 0.0460 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.24%
# Alpha: 0.001  | Max_Iter: 3000 | R² Treino: 0.0460 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.24%
# Alpha: 0.001  | Max_Iter: 1000 | R² Treino: 0.0461 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.27%
# Alpha: 0.001  | Max_Iter: 2000 | R² Treino: 0.0461 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.27%
# Alpha: 0.001  | Max_Iter: 3000 | R² Treino: 0.0461 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.27%
# Alpha: 0.01   | Max_Iter: 1000 | R² Treino: 0.0441 | R² Val: 0.0389 | RMSE Val: 21.42 | MAPE Val: 867.54%
# Alpha: 0.01   | Max_Iter: 2000 | R² Treino: 0.0441 | R² Val: 0.0389 | RMSE Val: 21.42 | MAPE Val: 867.54%
# Alpha: 0.01   | Max_Iter: 3000 | R² Treino: 0.0441 | R² Val: 0.0389 | RMSE Val: 21.42 | MAPE Val: 867.54%
# Alpha: 0.01   | Max_Iter: 1000 | R² Treino: 0.0446 | R² Val: 0.0393 | RMSE Val: 21.42 | MAPE Val: 867.71%
# Alpha: 0.01   | Max_Iter: 2000 | R² Treino: 0.0446 | R² Val: 0.0393 | RMSE Val: 21.42 | MAPE Val: 867.71%
# Alpha: 0.01   | Max_Iter: 3000 | R² Treino: 0.0446 | R² Val: 0.0393 | RMSE Val: 21.42 | MAPE Val: 867.71%
# Alpha: 0.01   | Max_Iter: 1000 | R² Treino: 0.0451 | R² Val: 0.0395 | RMSE Val: 21.42 | MAPE Val: 867.91%
# Alpha: 0.01   | Max_Iter: 2000 | R² Treino: 0.0451 | R² Val: 0.0395 | RMSE Val: 21.42 | MAPE Val: 867.91%
# Alpha: 0.01   | Max_Iter: 3000 | R² Treino: 0.0451 | R² Val: 0.0395 | RMSE Val: 21.42 | MAPE Val: 867.91%
# Alpha: 0.01   | Max_Iter: 1000 | R² Treino: 0.0455 | R² Val: 0.0398 | RMSE Val: 21.41 | MAPE Val: 868.15%
# Alpha: 0.01   | Max_Iter: 2000 | R² Treino: 0.0455 | R² Val: 0.0398 | RMSE Val: 21.41 | MAPE Val: 868.15%
# Alpha: 0.01   | Max_Iter: 3000 | R² Treino: 0.0455 | R² Val: 0.0398 | RMSE Val: 21.41 | MAPE Val: 868.15%
# Alpha: 0.01   | Max_Iter: 1000 | R² Treino: 0.0458 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.45%
# Alpha: 0.01   | Max_Iter: 2000 | R² Treino: 0.0458 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.45%
# Alpha: 0.01   | Max_Iter: 3000 | R² Treino: 0.0458 | R² Val: 0.0399 | RMSE Val: 21.41 | MAPE Val: 868.45%
# Alpha: 0.1    | Max_Iter: 1000 | R² Treino: 0.0271 | R² Val: 0.0256 | RMSE Val: 21.57 | MAPE Val: 867.70%
# Alpha: 0.1    | Max_Iter: 2000 | R² Treino: 0.0271 | R² Val: 0.0256 | RMSE Val: 21.57 | MAPE Val: 867.70%
# Alpha: 0.1    | Max_Iter: 3000 | R² Treino: 0.0271 | R² Val: 0.0256 | RMSE Val: 21.57 | MAPE Val: 867.70%
# Alpha: 0.1    | Max_Iter: 1000 | R² Treino: 0.0285 | R² Val: 0.0267 | RMSE Val: 21.56 | MAPE Val: 867.64%
# Alpha: 0.1    | Max_Iter: 2000 | R² Treino: 0.0285 | R² Val: 0.0267 | RMSE Val: 21.56 | MAPE Val: 867.64%
# Alpha: 0.1    | Max_Iter: 3000 | R² Treino: 0.0285 | R² Val: 0.0267 | RMSE Val: 21.56 | MAPE Val: 867.64%
# Alpha: 0.1    | Max_Iter: 1000 | R² Treino: 0.0305 | R² Val: 0.0284 | RMSE Val: 21.54 | MAPE Val: 867.68%
# Alpha: 0.1    | Max_Iter: 2000 | R² Treino: 0.0305 | R² Val: 0.0284 | RMSE Val: 21.54 | MAPE Val: 867.68%
# Alpha: 0.1    | Max_Iter: 3000 | R² Treino: 0.0305 | R² Val: 0.0284 | RMSE Val: 21.54 | MAPE Val: 867.68%
# Alpha: 0.1    | Max_Iter: 1000 | R² Treino: 0.0334 | R² Val: 0.0308 | RMSE Val: 21.51 | MAPE Val: 867.77%
# Alpha: 0.1    | Max_Iter: 2000 | R² Treino: 0.0334 | R² Val: 0.0308 | RMSE Val: 21.51 | MAPE Val: 867.77%
# Alpha: 0.1    | Max_Iter: 3000 | R² Treino: 0.0334 | R² Val: 0.0308 | RMSE Val: 21.51 | MAPE Val: 867.77%
# Alpha: 0.1    | Max_Iter: 1000 | R² Treino: 0.0381 | R² Val: 0.0347 | RMSE Val: 21.47 | MAPE Val: 868.11%
# Alpha: 0.1    | Max_Iter: 2000 | R² Treino: 0.0381 | R² Val: 0.0347 | RMSE Val: 21.47 | MAPE Val: 868.11%
# Alpha: 0.1    | Max_Iter: 3000 | R² Treino: 0.0381 | R² Val: 0.0347 | RMSE Val: 21.47 | MAPE Val: 868.11%
# Alpha: 1.0    | Max_Iter: 1000 | R² Treino: 0.0100 | R² Val: 0.0101 | RMSE Val: 21.74 | MAPE Val: 868.71%
# Alpha: 1.0    | Max_Iter: 2000 | R² Treino: 0.0100 | R² Val: 0.0101 | RMSE Val: 21.74 | MAPE Val: 868.71%
# Alpha: 1.0    | Max_Iter: 3000 | R² Treino: 0.0100 | R² Val: 0.0101 | RMSE Val: 21.74 | MAPE Val: 868.71%
# Alpha: 1.0    | Max_Iter: 1000 | R² Treino: 0.0087 | R² Val: 0.0089 | RMSE Val: 21.75 | MAPE Val: 869.08%
# Alpha: 1.0    | Max_Iter: 2000 | R² Treino: 0.0087 | R² Val: 0.0089 | RMSE Val: 21.75 | MAPE Val: 869.08%
# Alpha: 1.0    | Max_Iter: 3000 | R² Treino: 0.0087 | R² Val: 0.0089 | RMSE Val: 21.75 | MAPE Val: 869.08%
# Alpha: 1.0    | Max_Iter: 1000 | R² Treino: 0.0078 | R² Val: 0.0081 | RMSE Val: 21.76 | MAPE Val: 869.40%
# Alpha: 1.0    | Max_Iter: 2000 | R² Treino: 0.0078 | R² Val: 0.0081 | RMSE Val: 21.76 | MAPE Val: 869.40%
# Alpha: 1.0    | Max_Iter: 3000 | R² Treino: 0.0078 | R² Val: 0.0081 | RMSE Val: 21.76 | MAPE Val: 869.40%
# Alpha: 1.0    | Max_Iter: 1000 | R² Treino: 0.0074 | R² Val: 0.0078 | RMSE Val: 21.77 | MAPE Val: 869.52%
# Alpha: 1.0    | Max_Iter: 2000 | R² Treino: 0.0074 | R² Val: 0.0078 | RMSE Val: 21.77 | MAPE Val: 869.52%
# Alpha: 1.0    | Max_Iter: 3000 | R² Treino: 0.0074 | R² Val: 0.0078 | RMSE Val: 21.77 | MAPE Val: 869.52%
# Alpha: 1.0    | Max_Iter: 1000 | R² Treino: 0.0074 | R² Val: 0.0078 | RMSE Val: 21.77 | MAPE Val: 869.56%
# Alpha: 1.0    | Max_Iter: 2000 | R² Treino: 0.0074 | R² Val: 0.0078 | RMSE Val: 21.77 | MAPE Val: 869.56%
# Alpha: 1.0    | Max_Iter: 3000 | R² Treino: 0.0074 | R² Val: 0.0078 | RMSE Val: 21.77 | MAPE Val: 869.56%
# ================================================================================
# -> VENCEDOR DO ENSAIO RIDGE:
# Melhor Alpha: 0.001
# Melhor L1_Ratio: 0.5
# Melhor Max_Iter: 1000
# Maior R² obtido na Validação: 0.0399

# %% [markdown]
# ## Passo 6 — União treino + validação

# %%
# Unir treino + validação para formar o conjunto final de treinamento
X_train_final = pd.concat([X_train, X_val])
y_train_final = pd.concat([y_train, y_val])

print(f"X_train_final shape: {X_train_final.shape}")
print(f"y_train_final shape: {y_train_final.shape}")

# %% [markdown]
# ## Passo 7 — Retreino com melhores parâmetros

# %%
alpha = 0.001
max_iter = 1000
l1_ratio = 0.5


# Treinando o modelo para ver as outras métricas de avaliação
model = ElasticNet(alpha=alpha, l1_ratio=l1_rat, max_iter=mi, random_state=42)
model.fit(X_train, y_train.values.ravel())

# Previsão de treino e validação
yhat_train = model.predict(X_train)
yhat_val = model.predict(X_val)

#Performance Train
r2_train = mt.r2_score(y_train, yhat_train)
mse_train = mt.mean_squared_error(y_train, yhat_train)
rmse_train = np.sqrt(mse_train)
mae_train = mt.mean_absolute_error(y_train, yhat_train)
mape_train = mt.mean_absolute_percentage_error(y_train, yhat_train)

#Performance Validation
r2_val = mt.r2_score(y_val, yhat_val)
mse_val = mt.mean_squared_error(y_val, yhat_val)
rmse_val = np.sqrt(mse_val)
mae_val = mt.mean_absolute_error(y_val, yhat_val)
mape_val = mt.mean_absolute_percentage_error(y_val, yhat_val)

# Métrica de Treinamento e Teste
print(f"MÉTRICAS TREINAMENTO:")
print(f"R² (Coef. Determinação): {r2_train:.4f}")
print(f"MSE (Erro Quadrático Médio): {mse_train:.2f}")
print(f"RMSE (Raiz do Erro Quadrático): {rmse_train:.2f}")
print(f"MAE (Erro Absoluto Médio): {mae_train:.2f}")
print(f"MAPE (Erro Percentual Médio): {mape_train * 100:.2f}%")
print("=" * 65)
print(f"MÉTRICAS VALDAÇÃO:")
print(f"R² (Coef. Determinação): {r2_val:.4f}")
print(f"MSE (Erro Quadrático Médio): {mse_val:.2f}")
print(f"RMSE (Raiz do Erro Quadrático): {rmse_val:.2f}")
print(f"MAE (Erro Absoluto Médio): {mae_val:.2f}")
print(f"MAPE (Erro Percentual Médio): {mape_val * 100:.2f}%")
# Out:
# MÉTRICAS TREINAMENTO:
# R² (Coef. Determinação): 0.0461
# MSE (Erro Quadrático Médio): 456.00
# RMSE (Raiz do Erro Quadrático): 21.35
# MAE (Erro Absoluto Médio): 17.00
# MAPE (Erro Percentual Médio): 865.41%
# =================================================================
# MÉTRICAS VALDAÇÃO:
# R² (Coef. Determinação): 0.0399
# MSE (Erro Quadrático Médio): 458.44
# RMSE (Raiz do Erro Quadrático): 21.41
# MAE (Erro Absoluto Médio): 17.04
# MAPE (Erro Percentual Médio): 868.27%

# %% [markdown]
# ## Passo 8 — Performance no teste

# %%
# ==============================================================================
# JUNTAR AS BASES E EXECUTAR O TESTE FINAL
# ==============================================================================
print("--- Executando o Teste Final ---")

# Juntando treino e validação para dar mais volume de dados ao KNN
X_train_final = pd.concat([X_train, X_val])
y_train_final = pd.concat([y_train, y_val])

# Treinando o modelo definitivo com o melhor K encontrado
model_final = ElasticNet(alpha=melhor_alpha, max_iter=melhor_max_iter, l1_ratio=melhor_l1_ratio, random_state=42)
model_final.fit(X_train_final, y_train_final.values.ravel())

# Previsão final usando o dataset de teste (que ficou isolado o tempo todo)
yhat_test = model_final.predict(X_test)

#Performance Test
r2_test = mt.r2_score(y_test, yhat_test)
mse_test = mt.mean_squared_error(y_test, yhat_test)
rmse_test = np.sqrt(mse_test)
mae_test = mt.mean_absolute_error(y_test, yhat_test)
mape_test = mt.mean_absolute_percentage_error(y_test, yhat_test)

# Métrica final de produção
print(f"MÉTRICAS NO DATASET DE TESTE:")
print(f"R² (Coef. Determinação): {r2_test:.4f}")
print(f"MSE (Erro Quadrático Médio): {mse_test:.2f}")
print(f"RMSE (Raiz do Erro Quadrático): {rmse_test:.2f}")
print(f"MAE (Erro Absoluto Médio): {mae_test:.2f}")
print(f"MAPE (Erro Percentual Médio): {mape_test * 100:.2f}%")
print("=" * 65)
# Out:
# --- Executando o Teste Final ---
# MÉTRICAS NO DATASET DE TESTE:
# R² (Coef. Determinação): 0.0511
# MSE (Erro Quadrático Médio): 462.01
# RMSE (Raiz do Erro Quadrático): 21.49
# MAE (Erro Absoluto Médio): 17.14
# MAPE (Erro Percentual Médio): 853.71%
# =================================================================

# %% [markdown]
# ## Passo 9 — Avaliar e registrar 3 insights
#
# **Insight 1 — [Título do Insight]**
# > [Descreva aqui o insight mais relevante observado no comportamento deste algoritmo com estes dados.]
#
# **Insight 2 — [Título do Insight]**
# > [Descreva aqui o segundo insight: diferença treino vs validação, comportamento dos hiperparâmetros, etc.]
#
# **Insight 3 — [Título do Insight]**
# > [Descreva aqui o terceiro insight: comparação com outras abordagens, limitações, ou pontos de atenção.]

# %% [markdown]
# ## Passo 10 — Quadro Comparativo — Diagnóstico Completo

# %%
data_comparativo = {
    'Conjunto': ['Treino (Default)', 'Validação (Default)', 'Treino (Tunado)', 'Validação (Tunado)', 'Teste (Final)'],
    'R²':    [r2_train_def,   r2_val_def,   '-', '-', r2_test],
    'RMSE':  [rmse_train_def, rmse_val_def, '-', '-', rmse_test],
    'MAE':   [mae_train_def,  mae_val_def,  '-', '-', mae_test],
    'MAPE':  [f'{mape_train_def*100:.2f}%', f'{mape_val_def*100:.2f}%', '-', '-', f'{mape_test*100:.2f}%'],
}
df_comparativo = pd.DataFrame(data_comparativo)
print("\n--- Quadro Comparativo — Diagnóstico Completo ---")
print(df_comparativo.to_string(index=False))
